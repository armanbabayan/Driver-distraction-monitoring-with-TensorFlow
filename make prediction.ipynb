# %%
# import dependencies
from utils.decorators import timer
from utils.prediction import resize_image, make_prediction

# %% [markdown]
# ## Make predictins

# %%
image_path = 'for testing/drinking.jpg'
model_path = 'saved_models/model_version2.h5'
class_names = ['drinking',
                 'hair and makeup',
                 'operating the radio',
                 'reaching behind',
                 'safe driving',
                 'talking on the phone - left',
                 'talking on the phone - right',
                 'talking to passenger',
                 'texting - left',
                 'texting - right']

# %%
make_prediction(image_path=image_path , model_path= model_path,class_list = class_names)
# Out:
# Finished 'make_prediction' in  0.01 minutes
# ('drinking', 100.0)
